# %% [markdown]
# ![maze.png](attachment:maze.png)

# %% [markdown]
# ## Given two funtions...
# ## `move_forward()` - which moves you forward one block and
# ## `turn()` - which turns you 90° clockwise
# ## Follow the path to the end.

# %%
tracker = 0

# %%
def moveForwards( ):
    
        global tracker 
        tracker += 1
        print('moved forward by one step.')

# %%
def turn( ):
    
        global tracker
        tracker -= 1
        print('turning right')
   
        print('turning left')

# %% [markdown]
# ## Now create a function called `walk()` to navigate the path.

# %%
walk()
